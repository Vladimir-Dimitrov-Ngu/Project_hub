# %%
from tqdm import tqdm, trange
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import docx
import warnings
import re
import time
from scipy import stats
import wmi
from sys import platform
from docx.oxml.ns import qn
from docx.oxml import OxmlElement
from docx.enum.text import WD_BREAK
from docx.enum.text import WD_ALIGN_PARAGRAPH
from docx.shared import Pt
warnings.filterwarnings('ignore')

# %%
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from catboost import CatBoostRegressor

# %% [markdown]
# ##### Характеристика системы

# %%
computer = wmi.WMI()
computer_info = computer.Win32_ComputerSystem()[0]
os_info = computer.Win32_OperatingSystem()[0]
proc_info = computer.Win32_Processor()[0]
gpu_info = computer.Win32_VideoController()[0]
os_name = os_info.Name.split('|')[0]
os_version = ' '.join([os_info.Version, os_info.BuildNumber])
system_ram = float(os_info.TotalVisibleMemorySize) / 1048576  # KB to GB

# %% [markdown]
# ## Предпросмотр данных

# %%
interesting_features = ['Мгновенная механическая скорость бурения ', 'Частота вращения шпинделя', 'Индекс углубки', 
                       'Глубина скважины (м)', 'Крутящий момент на шпинделе', 'Давление промывочной жидкости', 
                       'Расход топлива мгновенный в час по шине CAN', 'Расход промывочной жидкости', 'Осевая нагрузка']

# %%
check = pd.read_csv('Result_23.csv')

# %%
check.shape[0]
# Out:
# 3253056

# %%
dt = pd.DataFrame()
for feature in tqdm(interesting_features, desc = 'Обработка признаков'):
    dt = dt.append(check[check['DESCRIPTION'] == feature][['VALUE', 'TIMESTAMP', 'DESCRIPTION']])
dt = dt.drop_duplicates()
# dt.to_csv('first_preprocessing.csv', encoding = 'utf-32')
df = dt.pivot_table(index = 'TIMESTAMP', columns = ['DESCRIPTION'], values = ['VALUE'])
df.reset_index(drop = False, inplace = True)
df['TIMESTAMP'] = df['TIMESTAMP'].replace(to_replace = '\.\d\d\d', value = '', regex = True)
timestamp = pd.to_datetime(df['TIMESTAMP'], format = '%Y-%m-%d %H:%M:%S')
df['TIMESTAMP'] = timestamp
# Out:
# Обработка признаков: 100%|███████████████████████████████████████████████████████████████| 9/9 [00:02<00:00,  3.73it/s]

# %%
print(df.isna().sum().sum())
# Out:
# 7015

# %%
total_sec = 60
new = pd.DataFrame()
for i in trange(df.shape[0], desc = 'Обработка пропусков'):
    if i == 0:
        if (df['TIMESTAMP'].iloc[i + 1] - df['TIMESTAMP'].iloc[i]).total_seconds() < total_sec:
            df.iloc[i: i + 2].fillna(method = 'bfill', inplace = True)
    elif i == df.shape[0] - 1:
        if (df['TIMESTAMP'].iloc[i] - df['TIMESTAMP'].iloc[i - 1]).total_seconds() < total_sec:
            df.iloc[i-1:i+1].fillna(method = 'ffill', inplace = True)
    else:
        if (df['TIMESTAMP'].iloc[i] - df['TIMESTAMP'].iloc[i - 1]).total_seconds() < total_sec:
            df.iloc[i-1:i+1].fillna(method = 'ffill', inplace = True)
        if (df['TIMESTAMP'].iloc[i + 1] - df['TIMESTAMP'].iloc[i]).total_seconds() < total_sec:
            df.iloc[i: i + 2].fillna(method = 'bfill', inplace = True)
# Out:
# Обработка пропусков:  74%|████████████████████████████████████████▋              | 67798/91567 [31:17<09:36, 41.26it/s]

# %%
print(7015 - df.isna().sum().sum())
# Out:
# 3545

# %%
df.dropna(inplace = True)

# %%
df = pd.read_csv('Чистый.csv', encoding = 'utf-32', index_col = 0, header = 1)
df.rename(columns = {'Unnamed: 1': 'TIMESTAMP'}, inplace = True)

# %% [markdown]
# ### Детекция на выбросы

# %%
interesting_features = list(df.columns)[1:14]

# %% [markdown]
# #### z-score

# %%
threshold = 2
dict_out_feat_z = {}
for feature in interesting_features:
    z = np.abs(stats.zscore(df[feature]))
    dict_out_feat_z[feature] = set(np.where(z > 2)[0])
set_all = set()
for feature in interesting_features:
    set_all = set_all|dict_out_feat_z[feature]

# %% [markdown]
# #### IQR-test

# %%
dict_out_feat_iqr = {}
for feature in interesting_features:
    Q1 = np.percentile(df[feature], 25, interpolation='midpoint')
    Q3 = np.percentile(df[feature], 75, interpolation='midpoint')
    IQR = Q3 - Q1
    upper=Q3+1.5*IQR
    lower=Q1-1.5*IQR
    iqr = np.where((df[feature] < lower) | (df[feature] > upper))
    dict_out_feat_iqr[feature] = iqr

# %% [markdown]
# ### Обучение алгоритма

# %% [markdown]
# #### Классический ML

# %% [markdown]
# ##### Линейные модели

# %%
target = [('VALUE','Частота вращения шпинделя')]
rmse = []
mse = []
r2 = []
mae = []
best_estimator = []
estimator = []
times = []
linear_models = [LinearRegression(), Lasso(), Ridge()]

# %%
X = df.drop(target + [df.columns[0]], axis = 1)
y = df[target]
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.9, shuffle=True, random_state=123)
parameters = {'alpha': np.arange(1, 100, 10)}

# %%
model = GridSearchCV(Lasso(), parameters, scoring = ['neg_mean_absolute_error', 'neg_mean_squared_error', 'r2'], refit =  'neg_mean_squared_error', cv = 2, n_jobs = -1)
model.fit(X, y)
# Out:
# GridSearchCV(cv=2, estimator=Lasso(), n_jobs=-1,
#              param_grid={'alpha': array([ 1, 11, 21, 31, 41, 51, 61, 71, 81, 91])},
#              refit='neg_mean_squared_error',
#              scoring=['neg_mean_absolute_error', 'neg_mean_squared_error',
#                       'r2'])

# %%
for linear_model in linear_models:
    linear = linear_model
    start_time = time.time()
    linear.fit(X_train, y_train)
    times.append(time.time() - start_time)
    y_pred = linear.predict(X_test)
    mse.append(round(mean_squared_error(y_test, y_pred), 1))
    rmse.append(round(mean_squared_error(y_test, y_pred) ** 0.5, 1))
    mae.append(round(mean_absolute_error(y_test, y_pred), 1))
    r2.append(round(r2_score(y_test, y_pred), 2))
    best_estimator.append('-')
    estimator.append(f'{str(linear_model).replace("()", "")}')
    if f'{linear_model}' == 'Ridge()' or f'{linear_model}' == 'Lasso()':
        start_time = time.time()
        linear= GridSearchCV(linear_model, parameters, scoring='neg_mean_squared_error',cv=5, n_jobs = -1)
        linear.fit(X_train, y_train)
        times.append(time.time() - start_time)
        y_pred = linear.predict(X_test)
        mse.append(round(mean_squared_error(y_test, y_pred), 1))
        rmse.append(round(mean_squared_error(y_test, y_pred) ** 0.5, 1))
        mae.append(round(mean_absolute_error(y_test, y_pred), 1))
        r2.append(round(r2_score(y_test, y_pred), 2))
        best_estimator.append(f'{linear.best_estimator_}')
        estimator.append(f'{str(linear_model).replace("()", "")}' + " opt")

# %%
dict_metrics = {'estimator': estimator,
              'mse': mse,
              'rmse': rmse,
              'r2': r2,
              'mae': mae,
              'best_estimator': best_estimator,
               'time': np.round(times, 1)}
metrics_linear = pd.DataFrame(dict_metrics)

# %% [markdown]
# ###### Деревянные модели

# %%
rmse = []
mse = []
r2 = []
mae = []
best_estimator = []
estimator = []
times = []

parameters_dt = {'max_depth': np.arange(3, 10, 2)}
parameters_rf = {'max_depth': np.arange(3, 10, 4), 'n_estimators': [300]}

# parameters_dt = {'criterion':['squared_error', 'friedman_mse'],'max_depth': np.arange(3, 10),
#               'max_leaf_nodes': np.arange(2, 10, 2), 'min_samples_split': np.arange(2, 5, 1)}
# parameters_rf = {'criterion':['squared_error', 'friedman_mse'],'max_depth': np.arange(3, 10, 2),
#               'max_leaf_nodes': np.arange(2, 10, 4), 'n_estimators': [200, 300]}
trees_models = [DecisionTreeRegressor(), RandomForestRegressor()]

# %%
for tree_model in tqdm(trees_models, desc = 'Обучаю модели'):
    X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.9, shuffle=True, random_state=123)
    tree = tree_model
    start_time = time.time()
    tree.fit(X_train, y_train)
    times.append(time.time() - start_time)
    y_pred = tree.predict(X_test)
    mse.append(round(mean_squared_error(y_test, y_pred), 1))
    rmse.append(round(mean_squared_error(y_test, y_pred) ** 0.5, 1))
    mae.append(round(mean_absolute_error(y_test, y_pred), 1))
    r2.append(round(r2_score(y_test, y_pred), 2))
    best_estimator.append('-')
    estimator.append(f'{str(tree_model).replace("()", "")}')
    if f'{tree_model}' == 'DecisionTreeRegressor()':
        start_time = time.time()
        tree= GridSearchCV(tree_model, parameters_dt, scoring='neg_mean_squared_error',cv=5, n_jobs = -1)
        tree.fit(X_train, y_train)
        times.append(time.time() - start_time)
        y_pred = tree.predict(X_test)
        mse.append(round(mean_squared_error(y_test, y_pred), 1))
        rmse.append(round(mean_squared_error(y_test, y_pred) ** 0.5, 1))
        mae.append(round(mean_absolute_error(y_test, y_pred), 1))
        r2.append(round(r2_score(y_test, y_pred), 2))
        best_estimator.append(f'{tree.best_estimator_}')
        estimator.append(f'{str(tree_model).replace("()", "")}' + " opt")
    if f'{tree_model}' == 'RandomForestRegressor()':
        start_time = time.time()
        tree= GridSearchCV(tree_model, parameters_rf, scoring='neg_mean_squared_error',cv=5, n_jobs = -1)
        tree.fit(X_train, y_train)
        times.append(time.time() - start_time)
        y_pred = tree.predict(X_test)
        mse.append(round(mean_squared_error(y_test, y_pred), 1))
        rmse.append(round(mean_squared_error(y_test, y_pred) ** 0.5, 1))
        mae.append(round(mean_absolute_error(y_test, y_pred), 1))
        r2.append(round(r2_score(y_test, y_pred), 2))
        best_estimator.append(f'{tree.best_estimator_}')
        estimator.append(f'{str(tree_model).replace("()", "")}' + " opt")
# Out:
# Обучаю модели: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2/2 [02:58<00:00, 89.36s/it]

# %%
dict_metrics = {'estimator': estimator,
              'mse': mse,
              'rmse': rmse,
              'r2': r2,
              'mae': mae,
              'best_estimator': best_estimator,
               'time': np.round(times, 1)}
metrics_tree = pd.DataFrame(dict_metrics)

# %% [markdown]
# ##### Градиентные бустинги

# %%
rmse = []
mse = []
r2 = []
mae = []
best_estimator = []
estimator = []
times = []

parameters_gr = {'n_estimators': [500, 1000],
#           'max_depth': [None, 3, 5,],
#           'min_samples_split': [2, 0.3, 0.5, n_samples//2, ],
#           'min_samples_leaf': [1, 0.3, 0.5, n_samples//2, ],
#           'criterion': ['friedman_mse', 'mae'],
#           'max_features': [None, 'sqrt', 'auto', 'log2', 0.3, 0.7, n_features//2, ],
         }
parameters_cat = {'learning_rate': [0.4, 0.1],
        # 'depth': [4, 6, 10],
        #'l2_leaf_reg': [1, 3, 5, 7, 9],
        'iterations': [500, 1000]}

boost_models = [GradientBoostingRegressor(), CatBoostRegressor(iterations=500, max_depth=10, learning_rate = 0.4)]

# %%
for boost_model in tqdm(boost_models, desc = 'Обучаю модели'):
    X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.9, shuffle=True, random_state=123)
    boost = boost_model
    start_time = time.time()
    boost.fit(X_train, y_train)
    times.append(time.time() - start_time)
    y_pred = boost.predict(X_test)
    mse.append(round(mean_squared_error(y_test, y_pred), 1))
    rmse.append(round(mean_squared_error(y_test, y_pred) ** 0.5, 1))
    mae.append(round(mean_absolute_error(y_test, y_pred), 1))
    r2.append(round(r2_score(y_test, y_pred), 2))
    best_estimator.append('-')
    estimator.append(f'{str(boost_model).replace("()", "")}')
    if f'{boost_model}' == 'GradientBoostingRegressor()':
        start_time = time.time()
        boost= GridSearchCV(boost_model, parameters_gr, scoring='neg_mean_squared_error',cv=5, n_jobs = -1)
        boost.fit(X, y)
        times.append(time.time() - start_time)
        y_pred = boost.predict(X_test)
        mse.append(round(mean_squared_error(y_test, y_pred), 1))
        rmse.append(round(mean_squared_error(y_test, y_pred) ** 0.5, 1))
        mae.append(round(mean_absolute_error(y_test, y_pred), 1))
        r2.append(round(r2_score(y_test, y_pred), 2))
        best_estimator.append(f'{boost.best_estimator_}')
        estimator.append(f'{str(boost_model).replace("()", "")}' + " opt")
    if f'{boost_model}' == 'CatBoostRegressor(iterations=500, max_depth=10, learning_rate = 0.4)':
        start_time = time.time()
        boost = GridSearchCV(boost_model, parameters_cat, scoring='neg_mean_squared_error',cv=5, n_jobs = -1)
        boost.fit(X_train, y_train)
        times.append(time.time() - start_time)
        y_pred = boost.predict(X_test)
        mse.append(round(mean_squared_error(y_test, y_pred), 1))
        rmse.append(round(mean_squared_error(y_test, y_pred) ** 0.5, 1))
        mae.append(round(mean_absolute_error(y_test, y_pred), 1))
        r2.append(round(r2_score(y_test, y_pred), 2))
        best_estimator.append(f'{boost.best_estimator_}')
        estimator.append(f'{str(boost_model).replace("()", "")}' + " opt")
# Out:
# Обучаю модели:  50%|███████████████████████████████████████████████████████████████████████████████▌                                                                               | 1/2 [04:28<04:28, 268.48s/it]
# 0:	learn: 1869.9016243	total: 186ms	remaining: 1m 32s
# 1:	learn: 1599.7620665	total: 215ms	remaining: 53.5s
# 2:	learn: 1403.3476810	total: 243ms	remaining: 40.2s
# 3:	learn: 1226.9247355	total: 268ms	remaining: 33.2s
# 4:	learn: 1077.6171043	total: 293ms	remaining: 29s
# 5:	learn: 976.2775605	total: 317ms	remaining: 26.1s
# 6:	learn: 887.7006388	total: 342ms	remaining: 24.1s
# 7:	learn: 796.7963697	total: 368ms	remaining: 22.6s
# 8:	learn: 719.3466016	total: 395ms	remaining: 21.5s
# 9:	learn: 657.1726109	total: 427ms	remaining: 20.9s
# 10:	learn: 599.0021706	total: 452ms	remaining: 20.1s
# 11:	learn: 544.4676376	total: 475ms	remaining: 19.3s
# 12:	learn: 496.5318351	total: 500ms	remaining: 18.7s
# 13:	learn: 454.5142776	total: 524ms	remaining: 18.2s
# 14:	learn: 411.6091096	total: 548ms	remaining: 17.7s
# 15:	learn: 380.2857645	total: 573ms	remaining: 17.3s
# 16:	learn: 344.2855167	total: 598ms	remaining: 17s
# 17:	learn: 323.4117362	total: 628ms	remaining: 16.8s
# 18:	learn: 310.8669226	total: 657ms	remaining: 16.6s
# 19:	learn: 282.9558370	total: 682ms	remaining: 16.4s
# 20:	learn: 266.7250312	total: 709ms	remaining: 16.2s
# 21:	learn: 253.0136273	total: 735ms	remaining: 16s
# 22:	learn: 242.4288584	total: 765ms	remaining: 15.9s
# 23:	learn: 235.3989604	total: 790ms	remaining: 15.7s
# 24:	learn: 226.0284904	total: 813ms	remaining: 15.4s
# 25:	learn: 219.6840784	total: 841ms	remaining: 15.3s
# 26:	learn: 214.2777251	total: 871ms	remaining: 15.3s
# 27:	learn: 209.8610336	total: 897ms	remaining: 15.1s
# 28:	learn: 201.1395195	total: 922ms	remaining: 15s
# 29:	learn: 192.6302286	total: 948ms	remaining: 14.9s
# 30:	learn: 188.4315482	total: 978ms	remaining: 14.8s
# 31:	learn: 181.7406465	total: 1.01s	remaining: 14.7s
# 32:	learn: 176.3704709	total: 1.04s	remaining: 14.7s
# 33:	learn: 174.0107847	total: 1.07s	remaining: 14.6s
# 34:	learn: 172.0964695	total: 1.1s	remaining: 14.6s
# 35:	learn: 167.1403085	total: 1.12s	remaining: 14.5s
# 36:	learn: 161.1063554	total: 1.15s	remaining: 14.4s
# 37:	learn: 157.1476701	total: 1.17s	remaining: 14.3s
# 38:	learn: 155.5993954	total: 1.2s	remaining: 14.2s
# 39:	learn: 152.9964835	total: 1.22s	remaining: 14.1s
# 40:	learn: 151.5037593	total: 1.25s	remaining: 13.9s
# 41:	learn: 147.6919119	total: 1.27s	remaining: 13.8s
# 42:	learn: 146.1999197	total: 1.3s	remaining: 13.8s
# 43:	learn: 144.9546188	total: 1.33s	remaining: 13.8s
# 44:	learn: 142.3829423	total: 1.35s	remaining: 13.7s
# 45:	learn: 140.0741886	total: 1.38s	remaining: 13.6s
# 46:	learn: 137.9807397	total: 1.4s	remaining: 13.5s
# 47:	learn: 135.4211612	total: 1.43s	remaining: 13.4s
# 48:	learn: 134.7248922	total: 1.45s	remaining: 13.4s
# 49:	learn: 131.1389024	total: 1.47s	remaining: 13.3s
# 50:	learn: 128.9668360	total: 1.5s	remaining: 13.2s
# 51:	learn: 127.1909935	total: 1.53s	remaining: 13.2s
# 52:	learn: 125.7094052	total: 1.56s	remaining: 13.1s
# 53:	learn: 124.4262445	total: 1.58s	remaining: 13.1s
# 54:	learn: 122.5910754	total: 1.6s	remaining: 13s
# 55:	learn: 120.3342864	total: 1.63s	remaining: 12.9s
# 56:	learn: 118.0559063	total: 1.65s	remaining: 12.9s
# 57:	learn: 116.3356046	total: 1.68s	remaining: 12.8s
# 58:	learn: 115.4441650	total: 1.71s	remaining: 12.7s
# 59:	learn: 114.3731275	total: 1.73s	remaining: 12.7s
# 60:	learn: 113.8531917	total: 1.76s	remaining: 12.7s
# 61:	learn: 112.5730363	total: 1.79s	remaining: 12.6s
# 62:	learn: 111.4831810	total: 1.81s	remaining: 12.6s
# 63:	learn: 110.2118648	total: 1.84s	remaining: 12.5s
# 64:	learn: 109.3878717	total: 1.86s	remaining: 12.5s
# 65:	learn: 108.9603699	total: 1.89s	remaining: 12.4s
# 66:	learn: 108.4067246	total: 1.91s	remaining: 12.4s
# 67:	learn: 107.9252276	total: 1.94s	remaining: 12.3s
# 68:	learn: 107.6151368	total: 1.96s	remaining: 12.3s
# 69:	learn: 106.9337223	total: 1.99s	remaining: 12.2s
# 70:	learn: 106.3324623	total: 2.02s	remaining: 12.2s
# 71:	learn: 105.6690147	total: 2.04s	remaining: 12.2s
# 72:	learn: 104.9272983	total: 2.07s	remaining: 12.1s
# 73:	learn: 104.0634263	total: 2.1s	remaining: 12.1s
# 74:	learn: 103.2545247	total: 2.12s	remaining: 12s
# 75:	learn: 101.7432110	total: 2.15s	remaining: 12s
# 76:	learn: 101.2311265	total: 2.17s	remaining: 11.9s
# 77:	learn: 100.6789354	total: 2.19s	remaining: 11.9s
# 78:	learn: 99.9665700	total: 2.22s	remaining: 11.8s
# 79:	learn: 99.4863624	total: 2.25s	remaining: 11.8s
# 80:	learn: 99.0829053	total: 2.28s	remaining: 11.8s
# 81:	learn: 98.5811960	total: 2.3s	remaining: 11.7s
# 82:	learn: 97.7881731	total: 2.33s	remaining: 11.7s
# 83:	learn: 96.9720976	total: 2.35s	remaining: 11.7s
# 84:	learn: 96.5776544	total: 2.38s	remaining: 11.6s
# 85:	learn: 96.1492488	total: 2.41s	remaining: 11.6s
# 86:	learn: 95.4598558	total: 2.43s	remaining: 11.5s
# 87:	learn: 94.5406033	total: 2.46s	remaining: 11.5s
# 88:	learn: 94.3004915	total: 2.49s	remaining: 11.5s
# 89:	learn: 93.9483703	total: 2.51s	remaining: 11.5s
# 90:	learn: 93.2357732	total: 2.54s	remaining: 11.4s
# 91:	learn: 92.2665744	total: 2.56s	remaining: 11.4s
# 92:	learn: 91.6787129	total: 2.59s	remaining: 11.3s
# 93:	learn: 91.4271314	total: 2.61s	remaining: 11.3s
# 94:	learn: 91.1975084	total: 2.64s	remaining: 11.2s
# 95:	learn: 90.9339989	total: 2.66s	remaining: 11.2s
# 96:	learn: 90.4735856	total: 2.69s	remaining: 11.2s
# 97:	learn: 90.2902699	total: 2.72s	remaining: 11.2s
# 98:	learn: 89.7599017	total: 2.74s	remaining: 11.1s
# 99:	learn: 89.3331990	total: 2.77s	remaining: 11.1s
# 100:	learn: 89.1010517	total: 2.79s	remaining: 11s
# 101:	learn: 88.6045892	total: 2.82s	remaining: 11s
# 102:	learn: 88.2964590	total: 2.84s	remaining: 11s
# 103:	learn: 88.0573266	total: 2.87s	remaining: 10.9s
# 104:	learn: 87.7606383	total: 2.89s	remaining: 10.9s
# 105:	learn: 87.4796058	total: 2.93s	remaining: 10.9s
# 106:	learn: 87.1647680	total: 2.96s	remaining: 10.9s
# 107:	learn: 86.8572556	total: 2.99s	remaining: 10.8s
# 108:	learn: 86.7183378	total: 3.01s	remaining: 10.8s
# 109:	learn: 86.1701146	total: 3.04s	remaining: 10.8s
# 110:	learn: 85.6785431	total: 3.06s	remaining: 10.7s
# 111:	learn: 85.2669667	total: 3.09s	remaining: 10.7s
# 112:	learn: 84.7671560	total: 3.11s	remaining: 10.7s
# 113:	learn: 84.5777315	total: 3.14s	remaining: 10.6s
# 114:	learn: 84.1430602	total: 3.17s	remaining: 10.6s
# 115:	learn: 83.9280550	total: 3.19s	remaining: 10.6s
# 116:	learn: 83.6251642	total: 3.22s	remaining: 10.5s
# 117:	learn: 83.2683894	total: 3.24s	remaining: 10.5s
# 118:	learn: 82.9171794	total: 3.27s	remaining: 10.5s
# 119:	learn: 82.4240793	total: 3.29s	remaining: 10.4s
# 120:	learn: 82.1393546	total: 3.32s	remaining: 10.4s
# 121:	learn: 81.8413047	total: 3.34s	remaining: 10.4s
# 122:	learn: 81.5076049	total: 3.37s	remaining: 10.3s
# 123:	learn: 81.2907773	total: 3.39s	remaining: 10.3s
# 124:	learn: 81.0211656	total: 3.42s	remaining: 10.3s
# 125:	learn: 80.8370659	total: 3.44s	remaining: 10.2s
# 126:	learn: 80.6365240	total: 3.47s	remaining: 10.2s
# 127:	learn: 80.4634211	total: 3.49s	remaining: 10.2s
# 128:	learn: 80.2847554	total: 3.52s	remaining: 10.1s
# 129:	learn: 80.0834226	total: 3.54s	remaining: 10.1s
# 130:	learn: 79.8542355	total: 3.56s	remaining: 10s
# 131:	learn: 79.6051181	total: 3.59s	remaining: 10s
# 132:	learn: 79.2833037	total: 3.62s	remaining: 9.98s
# 133:	learn: 79.1375760	total: 3.64s	remaining: 9.95s
# 134:	learn: 78.9135365	total: 3.67s	remaining: 9.92s
# 135:	learn: 78.7046271	total: 3.69s	remaining: 9.88s
# 136:	learn: 78.4339156	total: 3.72s	remaining: 9.85s
# 137:	learn: 78.2217954	total: 3.74s	remaining: 9.82s
# 138:	learn: 77.9903522	total: 3.77s	remaining: 9.79s
# 139:	learn: 77.8379558	total: 3.79s	remaining: 9.76s
# 140:	learn: 77.5864145	total: 3.82s	remaining: 9.73s
# 141:	learn: 77.3407711	total: 3.85s	remaining: 9.7s
# 142:	learn: 77.1549949	total: 3.87s	remaining: 9.67s
# 143:	learn: 76.7382261	total: 3.9s	remaining: 9.63s
# 144:	learn: 76.5599475	total: 3.92s	remaining: 9.61s
# 145:	learn: 76.4081049	total: 3.95s	remaining: 9.57s
# 146:	learn: 76.2429010	total: 3.97s	remaining: 9.54s
# 147:	learn: 76.0579463	total: 4s	remaining: 9.51s
# 148:	learn: 75.8992720	total: 4.02s	remaining: 9.48s
# 149:	learn: 75.7431184	total: 4.05s	remaining: 9.45s
# 150:	learn: 75.6134498	total: 4.07s	remaining: 9.42s
# 151:	learn: 75.3951056	total: 4.1s	remaining: 9.39s
# 152:	learn: 75.2542253	total: 4.12s	remaining: 9.35s
# 153:	learn: 74.8475918	total: 4.15s	remaining: 9.32s
# 154:	learn: 74.5962831	total: 4.17s	remaining: 9.29s
# 155:	learn: 74.3890921	total: 4.2s	remaining: 9.26s
# 156:	learn: 74.2899803	total: 4.22s	remaining: 9.23s
# 157:	learn: 74.0820003	total: 4.25s	remaining: 9.19s
# 158:	learn: 73.9148026	total: 4.27s	remaining: 9.16s
# 159:	learn: 73.7304628	total: 4.3s	remaining: 9.13s
# 160:	learn: 73.6269773	total: 4.32s	remaining: 9.1s
# 161:	learn: 73.3801209	total: 4.35s	remaining: 9.07s
# 162:	learn: 73.2184320	total: 4.37s	remaining: 9.04s
# 163:	learn: 73.0385669	total: 4.39s	remaining: 9s
# 164:	learn: 72.8766025	total: 4.42s	remaining: 8.97s
# 165:	learn: 72.8003325	total: 4.44s	remaining: 8.94s
# 166:	learn: 72.6305646	total: 4.47s	remaining: 8.91s
# 167:	learn: 72.5704036	total: 4.49s	remaining: 8.88s
# 168:	learn: 72.3532422	total: 4.52s	remaining: 8.85s
# 169:	learn: 72.1790863	total: 4.54s	remaining: 8.82s
# 170:	learn: 71.9915390	total: 4.57s	remaining: 8.79s
# 171:	learn: 71.8667228	total: 4.59s	remaining: 8.76s
# 172:	learn: 71.6797580	total: 4.62s	remaining: 8.72s
# 173:	learn: 71.5619179	total: 4.64s	remaining: 8.69s
# 174:	learn: 71.3925354	total: 4.66s	remaining: 8.66s
# 175:	learn: 71.2198190	total: 4.69s	remaining: 8.64s
# 176:	learn: 71.0335671	total: 4.72s	remaining: 8.61s
# 177:	learn: 70.8469742	total: 4.74s	remaining: 8.58s
# 178:	learn: 70.7029086	total: 4.77s	remaining: 8.55s
# 179:	learn: 70.3753535	total: 4.79s	remaining: 8.52s
# 180:	learn: 70.2305005	total: 4.82s	remaining: 8.49s
# 181:	learn: 70.1815268	total: 4.84s	remaining: 8.46s
# 182:	learn: 70.0664309	total: 4.87s	remaining: 8.43s
# 183:	learn: 69.9526261	total: 4.89s	remaining: 8.4s
# 184:	learn: 69.8803635	total: 4.92s	remaining: 8.37s
# 185:	learn: 69.7121231	total: 4.95s	remaining: 8.35s
# 186:	learn: 69.6131164	total: 4.97s	remaining: 8.32s
# 187:	learn: 69.3854359	total: 5s	remaining: 8.29s
# 188:	learn: 69.1909564	total: 5.02s	remaining: 8.26s
# 189:	learn: 69.1293270	total: 5.04s	remaining: 8.23s
# 190:	learn: 68.9162696	total: 5.07s	remaining: 8.2s
# 191:	learn: 68.6853774	total: 5.09s	remaining: 8.17s
# 192:	learn: 68.3849105	total: 5.12s	remaining: 8.15s
# 193:	learn: 68.2008936	total: 5.15s	remaining: 8.12s
# 194:	learn: 68.0892541	total: 5.17s	remaining: 8.09s
# 195:	learn: 67.9425911	total: 5.2s	remaining: 8.06s
# 196:	learn: 67.7182067	total: 5.22s	remaining: 8.03s
# 197:	learn: 67.5962752	total: 5.25s	remaining: 8s
# 198:	learn: 67.5114452	total: 5.27s	remaining: 7.97s
# 199:	learn: 67.3751433	total: 5.29s	remaining: 7.94s
# 200:	learn: 67.2500966	total: 5.32s	remaining: 7.91s
# 201:	learn: 67.1879845	total: 5.35s	remaining: 7.89s
# 202:	learn: 67.1186417	total: 5.37s	remaining: 7.86s
# 203:	learn: 67.0646294	total: 5.39s	remaining: 7.83s
# 204:	learn: 66.9831231	total: 5.42s	remaining: 7.8s
# 205:	learn: 66.9055301	total: 5.44s	remaining: 7.77s
# 206:	learn: 66.8016829	total: 5.47s	remaining: 7.74s
# 207:	learn: 66.7023970	total: 5.49s	remaining: 7.71s
# 208:	learn: 66.5578510	total: 5.52s	remaining: 7.68s
# 209:	learn: 66.3647293	total: 5.54s	remaining: 7.65s
# 210:	learn: 66.2889008	total: 5.57s	remaining: 7.63s
# 211:	learn: 66.1841934	total: 5.59s	remaining: 7.6s
# 212:	learn: 66.1115764	total: 5.62s	remaining: 7.57s
# 213:	learn: 66.0451031	total: 5.64s	remaining: 7.54s
# 214:	learn: 65.8674431	total: 5.67s	remaining: 7.51s
# 215:	learn: 65.7524743	total: 5.69s	remaining: 7.48s
# 216:	learn: 65.5926343	total: 5.72s	remaining: 7.46s
# 217:	learn: 65.4801067	total: 5.74s	remaining: 7.43s
# 218:	learn: 65.3857490	total: 5.77s	remaining: 7.4s
# 219:	learn: 65.2003048	total: 5.8s	remaining: 7.38s
# 220:	learn: 65.1026630	total: 5.82s	remaining: 7.35s
# 221:	learn: 64.9818271	total: 5.84s	remaining: 7.32s
# 222:	learn: 64.8445805	total: 5.87s	remaining: 7.29s
# 223:	learn: 64.6835573	total: 5.9s	remaining: 7.27s
# 224:	learn: 64.5103566	total: 5.93s	remaining: 7.25s
# 225:	learn: 64.4186364	total: 5.95s	remaining: 7.22s
# 226:	learn: 64.2775172	total: 5.98s	remaining: 7.19s
# 227:	learn: 64.1793143	total: 6s	remaining: 7.16s
# 228:	learn: 64.1067726	total: 6.03s	remaining: 7.13s
# 229:	learn: 64.0587234	total: 6.05s	remaining: 7.1s
# 230:	learn: 63.9510211	total: 6.08s	remaining: 7.08s
# 231:	learn: 63.8342401	total: 6.1s	remaining: 7.05s
# 232:	learn: 63.6695250	total: 6.13s	remaining: 7.02s
# 233:	learn: 63.5522375	total: 6.15s	remaining: 6.99s
# 234:	learn: 63.3907188	total: 6.17s	remaining: 6.96s
# 235:	learn: 63.2341848	total: 6.2s	remaining: 6.94s
# 236:	learn: 63.1891283	total: 6.23s	remaining: 6.91s
# 237:	learn: 63.0519393	total: 6.25s	remaining: 6.88s
# 238:	learn: 62.8877235	total: 6.28s	remaining: 6.85s
# 239:	learn: 62.7962437	total: 6.3s	remaining: 6.83s
# 240:	learn: 62.6753120	total: 6.33s	remaining: 6.8s
# 241:	learn: 62.5528101	total: 6.35s	remaining: 6.77s
# 242:	learn: 62.4713321	total: 6.37s	remaining: 6.74s
# 243:	learn: 62.3227788	total: 6.4s	remaining: 6.71s
# 244:	learn: 62.2073161	total: 6.43s	remaining: 6.69s
# 245:	learn: 62.1027929	total: 6.45s	remaining: 6.66s
# 246:	learn: 62.0361188	total: 6.47s	remaining: 6.63s
# 247:	learn: 61.8947065	total: 6.5s	remaining: 6.61s
# 248:	learn: 61.7684027	total: 6.53s	remaining: 6.58s
# 249:	learn: 61.6320756	total: 6.55s	remaining: 6.55s
# 250:	learn: 61.5402414	total: 6.58s	remaining: 6.52s
# 251:	learn: 61.4208547	total: 6.6s	remaining: 6.49s
# 252:	learn: 61.3374354	total: 6.62s	remaining: 6.47s
# 253:	learn: 61.2535626	total: 6.65s	remaining: 6.44s
# 254:	learn: 61.1925208	total: 6.68s	remaining: 6.42s
# 255:	learn: 61.0995796	total: 6.7s	remaining: 6.39s
# 256:	learn: 60.9783875	total: 6.73s	remaining: 6.36s
# 257:	learn: 60.8898575	total: 6.75s	remaining: 6.33s
# 258:	learn: 60.7400937	total: 6.78s	remaining: 6.3s
# 259:	learn: 60.6684202	total: 6.8s	remaining: 6.28s
# 260:	learn: 60.6190891	total: 6.82s	remaining: 6.25s
# 261:	learn: 60.5405335	total: 6.85s	remaining: 6.22s
# 262:	learn: 60.4351761	total: 6.88s	remaining: 6.2s
# 263:	learn: 60.2831558	total: 6.9s	remaining: 6.17s
# 264:	learn: 60.1930252	total: 6.93s	remaining: 6.14s
# 265:	learn: 60.0889835	total: 6.95s	remaining: 6.12s
# 266:	learn: 59.9531753	total: 6.98s	remaining: 6.09s
# 267:	learn: 59.8462969	total: 7s	remaining: 6.06s
# 268:	learn: 59.7048213	total: 7.03s	remaining: 6.03s
# 269:	learn: 59.6391787	total: 7.05s	remaining: 6.01s
# 270:	learn: 59.5136394	total: 7.08s	remaining: 5.98s
# 271:	learn: 59.4148215	total: 7.1s	remaining: 5.95s
# 272:	learn: 59.3355779	total: 7.13s	remaining: 5.93s
# 273:	learn: 59.2473826	total: 7.15s	remaining: 5.9s
# 274:	learn: 59.1739401	total: 7.18s	remaining: 5.87s
# 275:	learn: 59.1009740	total: 7.2s	remaining: 5.84s
# 276:	learn: 59.0375911	total: 7.22s	remaining: 5.82s
# 277:	learn: 58.9687921	total: 7.25s	remaining: 5.79s
# 278:	learn: 58.8889192	total: 7.28s	remaining: 5.76s
# 279:	learn: 58.7916756	total: 7.3s	remaining: 5.74s
# 280:	learn: 58.7229544	total: 7.33s	remaining: 5.71s
# 281:	learn: 58.6273802	total: 7.35s	remaining: 5.68s
# 282:	learn: 58.5522209	total: 7.38s	remaining: 5.66s
# 283:	learn: 58.4573004	total: 7.4s	remaining: 5.63s
# 284:	learn: 58.3772868	total: 7.43s	remaining: 5.6s
# 285:	learn: 58.2876583	total: 7.45s	remaining: 5.58s
# 286:	learn: 58.1766689	total: 7.47s	remaining: 5.55s
# 287:	learn: 58.0889074	total: 7.5s	remaining: 5.52s
# 288:	learn: 58.0552517	total: 7.53s	remaining: 5.49s
# 289:	learn: 57.9819383	total: 7.55s	remaining: 5.47s
# 290:	learn: 57.9091395	total: 7.58s	remaining: 5.44s
# 291:	learn: 57.8306858	total: 7.6s	remaining: 5.41s
# 292:	learn: 57.7566075	total: 7.63s	remaining: 5.39s
# 293:	learn: 57.6565209	total: 7.65s	remaining: 5.36s
# 294:	learn: 57.6217231	total: 7.67s	remaining: 5.33s
# 295:	learn: 57.5997511	total: 7.7s	remaining: 5.31s
# 296:	learn: 57.5668806	total: 7.72s	remaining: 5.28s
# 297:	learn: 57.5220918	total: 7.75s	remaining: 5.25s
# 298:	learn: 57.4972425	total: 7.78s	remaining: 5.23s
# 299:	learn: 57.4221638	total: 7.8s	remaining: 5.2s
# 300:	learn: 57.3279349	total: 7.82s	remaining: 5.17s
# 301:	learn: 57.2724128	total: 7.85s	remaining: 5.15s
# 302:	learn: 57.1761693	total: 7.87s	remaining: 5.12s
# 303:	learn: 57.1167930	total: 7.9s	remaining: 5.09s
# 304:	learn: 57.0347577	total: 7.93s	remaining: 5.07s
# 305:	learn: 56.9335005	total: 7.95s	remaining: 5.04s
# 306:	learn: 56.8360382	total: 7.98s	remaining: 5.02s
# 307:	learn: 56.7544761	total: 8.01s	remaining: 4.99s
# 308:	learn: 56.6058216	total: 8.03s	remaining: 4.96s
# 309:	learn: 56.5346125	total: 8.05s	remaining: 4.94s
# 310:	learn: 56.4417523	total: 8.08s	remaining: 4.91s
# 311:	learn: 56.3390644	total: 8.11s	remaining: 4.88s
# 312:	learn: 56.3037996	total: 8.13s	remaining: 4.86s
# 313:	learn: 56.1390713	total: 8.15s	remaining: 4.83s
# 314:	learn: 56.0603674	total: 8.18s	remaining: 4.8s
# 315:	learn: 56.0124337	total: 8.21s	remaining: 4.78s
# 316:	learn: 55.9108885	total: 8.23s	remaining: 4.75s
# 317:	learn: 55.8618839	total: 8.26s	remaining: 4.72s
# 318:	learn: 55.8174290	total: 8.28s	remaining: 4.7s
# 319:	learn: 55.7496201	total: 8.3s	remaining: 4.67s
# 320:	learn: 55.6798431	total: 8.33s	remaining: 4.64s
# 321:	learn: 55.6270499	total: 8.35s	remaining: 4.62s
# 322:	learn: 55.5269554	total: 8.38s	remaining: 4.59s
# 323:	learn: 55.4761017	total: 8.4s	remaining: 4.57s
# 324:	learn: 55.4336265	total: 8.43s	remaining: 4.54s
# 325:	learn: 55.3352124	total: 8.45s	remaining: 4.51s
# 326:	learn: 55.2868422	total: 8.48s	remaining: 4.49s
# 327:	learn: 55.2263234	total: 8.5s	remaining: 4.46s
# 328:	learn: 55.1899151	total: 8.53s	remaining: 4.43s
# 329:	learn: 55.1496350	total: 8.55s	remaining: 4.41s
# 330:	learn: 55.0874303	total: 8.58s	remaining: 4.38s
# 331:	learn: 55.0379009	total: 8.6s	remaining: 4.35s
# 332:	learn: 54.9764347	total: 8.63s	remaining: 4.33s
# 333:	learn: 54.9143442	total: 8.65s	remaining: 4.3s
# 334:	learn: 54.8570915	total: 8.68s	remaining: 4.27s
# 335:	learn: 54.8009529	total: 8.7s	remaining: 4.25s
# 336:	learn: 54.7208149	total: 8.73s	remaining: 4.22s
# 337:	learn: 54.6714833	total: 8.76s	remaining: 4.2s
# 338:	learn: 54.6208860	total: 8.78s	remaining: 4.17s
# 339:	learn: 54.5775445	total: 8.8s	remaining: 4.14s
# 340:	learn: 54.4104885	total: 8.83s	remaining: 4.12s
# 341:	learn: 54.3542286	total: 8.86s	remaining: 4.09s
# 342:	learn: 54.2778089	total: 8.88s	remaining: 4.07s
# 343:	learn: 54.2138925	total: 8.91s	remaining: 4.04s
# 344:	learn: 54.1737154	total: 8.94s	remaining: 4.01s
# 345:	learn: 54.0819187	total: 8.96s	remaining: 3.99s
# 346:	learn: 53.9889984	total: 8.99s	remaining: 3.96s
# 347:	learn: 53.9401501	total: 9.01s	remaining: 3.94s
# 348:	learn: 53.8810565	total: 9.04s	remaining: 3.91s
# 349:	learn: 53.8076288	total: 9.06s	remaining: 3.88s
# 350:	learn: 53.7324069	total: 9.09s	remaining: 3.86s
# 351:	learn: 53.6172516	total: 9.11s	remaining: 3.83s
# 352:	learn: 53.5644093	total: 9.14s	remaining: 3.81s
# 353:	learn: 53.5234805	total: 9.16s	remaining: 3.78s
# 354:	learn: 53.4373771	total: 9.19s	remaining: 3.75s
# 355:	learn: 53.3905202	total: 9.21s	remaining: 3.73s
# 356:	learn: 53.3377134	total: 9.23s	remaining: 3.7s
# 357:	learn: 53.2904285	total: 9.26s	remaining: 3.67s
# 358:	learn: 53.2330158	total: 9.29s	remaining: 3.65s
# 359:	learn: 53.1835754	total: 9.31s	remaining: 3.62s
# 360:	learn: 53.0873407	total: 9.34s	remaining: 3.6s
# 361:	learn: 52.9192010	total: 9.36s	remaining: 3.57s
# 362:	learn: 52.8888363	total: 9.38s	remaining: 3.54s
# 363:	learn: 52.8139215	total: 9.41s	remaining: 3.52s
# 364:	learn: 52.7569135	total: 9.43s	remaining: 3.49s
# 365:	learn: 52.7030602	total: 9.46s	remaining: 3.46s
# 366:	learn: 52.6175665	total: 9.48s	remaining: 3.44s
# 367:	learn: 52.5646541	total: 9.51s	remaining: 3.41s
# 368:	learn: 52.4617041	total: 9.54s	remaining: 3.38s
# 369:	learn: 52.4385227	total: 9.56s	remaining: 3.36s
# 370:	learn: 52.3983033	total: 9.58s	remaining: 3.33s
# 371:	learn: 52.3479255	total: 9.61s	remaining: 3.31s
# 372:	learn: 52.2818332	total: 9.63s	remaining: 3.28s
# 373:	learn: 52.1984599	total: 9.66s	remaining: 3.25s
# 374:	learn: 52.1713976	total: 9.68s	remaining: 3.23s
# 375:	learn: 52.0930572	total: 9.71s	remaining: 3.2s
# 376:	learn: 52.0614766	total: 9.74s	remaining: 3.18s
# 377:	learn: 51.9869359	total: 9.76s	remaining: 3.15s
# 378:	learn: 51.9245934	total: 9.79s	remaining: 3.12s
# 379:	learn: 51.8445796	total: 9.81s	remaining: 3.1s
# 380:	learn: 51.7806625	total: 9.84s	remaining: 3.07s
# 381:	learn: 51.6956040	total: 9.86s	remaining: 3.05s
# 382:	learn: 51.6464554	total: 9.89s	remaining: 3.02s
# 383:	learn: 51.6189123	total: 9.91s	remaining: 2.99s
# 384:	learn: 51.4923833	total: 9.94s	remaining: 2.97s
# 385:	learn: 51.4160789	total: 9.97s	remaining: 2.94s
# 386:	learn: 51.3623341	total: 9.99s	remaining: 2.92s
# 387:	learn: 51.3113233	total: 10s	remaining: 2.89s
# 388:	learn: 51.2897872	total: 10s	remaining: 2.87s
# 389:	learn: 51.2155652	total: 10.1s	remaining: 2.84s
# 390:	learn: 51.1835188	total: 10.1s	remaining: 2.81s
# 391:	learn: 51.1390631	total: 10.1s	remaining: 2.79s
# 392:	learn: 51.0277113	total: 10.1s	remaining: 2.76s
# 393:	learn: 50.9626714	total: 10.2s	remaining: 2.74s
# 394:	learn: 50.8817651	total: 10.2s	remaining: 2.71s
# 395:	learn: 50.8233117	total: 10.2s	remaining: 2.69s
# 396:	learn: 50.8023812	total: 10.3s	remaining: 2.66s
# 397:	learn: 50.7612322	total: 10.3s	remaining: 2.64s
# 398:	learn: 50.7142652	total: 10.3s	remaining: 2.61s
# 399:	learn: 50.6594292	total: 10.3s	remaining: 2.59s
# 400:	learn: 50.6217815	total: 10.4s	remaining: 2.56s
# 401:	learn: 50.5921963	total: 10.4s	remaining: 2.54s
# 402:	learn: 50.5537412	total: 10.4s	remaining: 2.51s
# 403:	learn: 50.5006591	total: 10.5s	remaining: 2.48s
# 404:	learn: 50.4449117	total: 10.5s	remaining: 2.46s
# 405:	learn: 50.3921203	total: 10.5s	remaining: 2.43s
# 406:	learn: 50.3192319	total: 10.5s	remaining: 2.41s
# 407:	learn: 50.2691590	total: 10.6s	remaining: 2.38s
# 408:	learn: 50.2146240	total: 10.6s	remaining: 2.35s
# 409:	learn: 50.1700118	total: 10.6s	remaining: 2.33s
# 410:	learn: 50.1093330	total: 10.6s	remaining: 2.3s
# 411:	learn: 50.0388842	total: 10.7s	remaining: 2.28s
# 412:	learn: 49.9938936	total: 10.7s	remaining: 2.25s
# 413:	learn: 49.9375100	total: 10.7s	remaining: 2.23s
# 414:	learn: 49.8659614	total: 10.7s	remaining: 2.2s
# 415:	learn: 49.7631107	total: 10.8s	remaining: 2.17s
# 416:	learn: 49.7332983	total: 10.8s	remaining: 2.15s
# 417:	learn: 49.7098621	total: 10.8s	remaining: 2.12s
# 418:	learn: 49.6751374	total: 10.8s	remaining: 2.1s
# 419:	learn: 49.6215008	total: 10.9s	remaining: 2.07s
# 420:	learn: 49.5384295	total: 10.9s	remaining: 2.04s
# 421:	learn: 49.4616381	total: 10.9s	remaining: 2.02s
# 422:	learn: 49.4078564	total: 10.9s	remaining: 1.99s
# 423:	learn: 49.3684854	total: 11s	remaining: 1.97s
# 424:	learn: 49.2686963	total: 11s	remaining: 1.94s
# 425:	learn: 49.2119600	total: 11s	remaining: 1.91s
# 426:	learn: 49.1610234	total: 11s	remaining: 1.89s
# 427:	learn: 49.1042232	total: 11.1s	remaining: 1.86s
# 428:	learn: 49.0571466	total: 11.1s	remaining: 1.84s
# 429:	learn: 49.0013935	total: 11.1s	remaining: 1.81s
# 430:	learn: 48.9343978	total: 11.2s	remaining: 1.78s
# 431:	learn: 48.9016783	total: 11.2s	remaining: 1.76s
# 432:	learn: 48.8503091	total: 11.2s	remaining: 1.73s
# 433:	learn: 48.7853145	total: 11.2s	remaining: 1.71s
# 434:	learn: 48.7367069	total: 11.3s	remaining: 1.68s
# 435:	learn: 48.7173200	total: 11.3s	remaining: 1.66s
# 436:	learn: 48.6689918	total: 11.3s	remaining: 1.63s
# 437:	learn: 48.6349693	total: 11.3s	remaining: 1.6s
# 438:	learn: 48.5762167	total: 11.4s	remaining: 1.58s
# 439:	learn: 48.5141641	total: 11.4s	remaining: 1.55s
# 440:	learn: 48.4592639	total: 11.4s	remaining: 1.52s
# 441:	learn: 48.4340296	total: 11.4s	remaining: 1.5s
# 442:	learn: 48.3809164	total: 11.5s	remaining: 1.47s
# 443:	learn: 48.3431363	total: 11.5s	remaining: 1.45s
# 444:	learn: 48.2998179	total: 11.5s	remaining: 1.42s
# 445:	learn: 48.2668167	total: 11.5s	remaining: 1.4s
# 446:	learn: 48.2237484	total: 11.6s	remaining: 1.37s
# 447:	learn: 48.1719097	total: 11.6s	remaining: 1.34s
# 448:	learn: 48.1104732	total: 11.6s	remaining: 1.32s
# 449:	learn: 48.0802571	total: 11.6s	remaining: 1.29s
# 450:	learn: 48.0704870	total: 11.7s	remaining: 1.27s
# 451:	learn: 48.0284822	total: 11.7s	remaining: 1.24s
# 452:	learn: 47.9743846	total: 11.7s	remaining: 1.21s
# 453:	learn: 47.8985587	total: 11.7s	remaining: 1.19s
# 454:	learn: 47.8402925	total: 11.8s	remaining: 1.16s
# 455:	learn: 47.8050227	total: 11.8s	remaining: 1.14s
# 456:	learn: 47.7737386	total: 11.8s	remaining: 1.11s
# 457:	learn: 47.7388190	total: 11.8s	remaining: 1.08s
# 458:	learn: 47.6851337	total: 11.9s	remaining: 1.06s
# 459:	learn: 47.6066973	total: 11.9s	remaining: 1.03s
# 460:	learn: 47.5546464	total: 11.9s	remaining: 1.01s
# 461:	learn: 47.5045448	total: 11.9s	remaining: 982ms
# 462:	learn: 47.4591320	total: 12s	remaining: 956ms
# 463:	learn: 47.4179407	total: 12s	remaining: 930ms
# 464:	learn: 47.3552634	total: 12s	remaining: 905ms
# 465:	learn: 47.3247150	total: 12s	remaining: 879ms
# 466:	learn: 47.2637711	total: 12.1s	remaining: 853ms
# 467:	learn: 47.2362814	total: 12.1s	remaining: 827ms
# 468:	learn: 47.2020027	total: 12.1s	remaining: 801ms
# 469:	learn: 47.1507358	total: 12.1s	remaining: 775ms
# 470:	learn: 47.1235883	total: 12.2s	remaining: 750ms
# 471:	learn: 47.0820573	total: 12.2s	remaining: 724ms
# 472:	learn: 47.0361989	total: 12.2s	remaining: 698ms
# 473:	learn: 46.9965333	total: 12.3s	remaining: 672ms
# 474:	learn: 46.9363938	total: 12.3s	remaining: 646ms
# 475:	learn: 46.9147948	total: 12.3s	remaining: 620ms
# 476:	learn: 46.8576584	total: 12.3s	remaining: 594ms
# 477:	learn: 46.8056036	total: 12.4s	remaining: 568ms
# 478:	learn: 46.7514060	total: 12.4s	remaining: 543ms
# 479:	learn: 46.6864711	total: 12.4s	remaining: 517ms
# 480:	learn: 46.6661757	total: 12.4s	remaining: 491ms
# 481:	learn: 46.6309588	total: 12.5s	remaining: 465ms
# 482:	learn: 46.6068510	total: 12.5s	remaining: 439ms
# 483:	learn: 46.5596323	total: 12.5s	remaining: 413ms
# 484:	learn: 46.5236076	total: 12.5s	remaining: 388ms
# 485:	learn: 46.4990609	total: 12.6s	remaining: 362ms
# 486:	learn: 46.4556532	total: 12.6s	remaining: 336ms
# 487:	learn: 46.4066410	total: 12.6s	remaining: 310ms
# 488:	learn: 46.3519422	total: 12.6s	remaining: 284ms
# 489:	learn: 46.2913574	total: 12.7s	remaining: 258ms
# 490:	learn: 46.2526780	total: 12.7s	remaining: 233ms
# 491:	learn: 46.2261978	total: 12.7s	remaining: 207ms
# 492:	learn: 46.1814517	total: 12.7s	remaining: 181ms
# 493:	learn: 46.1553139	total: 12.8s	remaining: 155ms
# 494:	learn: 46.0918240	total: 12.8s	remaining: 129ms
# 495:	learn: 46.0509426	total: 12.8s	remaining: 103ms
# 496:	learn: 45.9997190	total: 12.8s	remaining: 77.5ms
# 497:	learn: 45.9246685	total: 12.9s	remaining: 51.7ms
# 498:	learn: 45.8855226	total: 12.9s	remaining: 25.8ms
# 499:	learn: 45.8543503	total: 12.9s	remaining: 0us
# Обучаю модели: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2/2 [04:41<00:00, 140.93s/it]

# %%
dict_metrics = {'estimator': estimator,
              'mse': mse,
              'rmse': rmse,
              'r2': r2,
              'mae': mae,
              'best_estimator': best_estimator,
               'time': np.round(times, 1)}
metrics_boost = pd.DataFrame(dict_metrics)

# %% [markdown]
# ## Создание документа

# %%
doc = docx.Document()
# задаем стиль текста по умолчанию
style = doc.styles['Normal']
# название шрифта
style.font.name = 'Times New Roman'
# размер шрифта
style.font.size = docx.shared.Pt(14)

# %%
line_spacing = 1.75
paragraph = doc.add_paragraph('Содержание\n')
run = paragraph.add_run()
fldChar = OxmlElement('w:fldChar')  # creates a new element
fldChar.set(qn('w:fldCharType'), 'begin')  # sets attribute on element
instrText = OxmlElement('w:instrText')
instrText.set(qn('xml:space'), 'preserve')  # sets attribute on element
instrText.text = 'TOC \\o "1-3" \\h \\z \\u'   # change 1-3 depending on heading levels you need

fldChar2 = OxmlElement('w:fldChar')
fldChar2.set(qn('w:fldCharType'), 'separate')
fldChar3 = OxmlElement('w:t')
fldChar3.text = "Right-click to update field."
fldChar2.append(fldChar3)

fldChar4 = OxmlElement('w:fldChar')
fldChar4.set(qn('w:fldCharType'), 'end')
r_element = run._r
r_element.append(fldChar)
r_element.append(instrText)
r_element.append(fldChar2)
r_element.append(fldChar4)
p_element = paragraph._p
doc.add_page_break()
# заголовок 1
head_1 = doc.add_heading('Запрос в SQL', level = 1)
head_1.alignment = WD_ALIGN_PARAGRAPH.CENTER
h_fmt = head_1.paragraph_format
h_fmt.line_spacing = 1.75
# параграф 
paragraph = doc.add_paragraph('SELECT df.ID, TIMESTAMP, dj.DESCRIPTION, VALUE  FROM DRILL_GEO_GAUGE_TRANS df \n\
LEFT JOIN DRILL_GEO_GAUGE_TYPE dj ON dj.ID = df.GAUGE_TYPE_ID \n\
ORDER BY df.ID;')
p_fmt = paragraph.paragraph_format
p_fmt.line_spacing = 1.75

# заголовок_i
head_i = doc.add_heading('Характеристика компьютера', level = 1)
h_fmt = head_i.paragraph_format
h_fmt.line_spacing = 1.75
paragraph = doc.add_paragraph('OS Name: {0}'.format(os_name))
paragraph = doc.add_paragraph('OS Version: {0}'.format(os_version))
paragraph = doc.add_paragraph('CPU: {0}'.format(proc_info.Name))
paragraph = doc.add_paragraph('RAM: {0} GB'.format(system_ram))
paragraph = doc.add_paragraph('Graphics Card: {0}'.format(gpu_info.Name))
p_fmt = paragraph.paragraph_format
p_fmt.line_spacing = 1.75

# заголовок 2
head_2 = doc.add_heading('Первичный осмотр данных', level = 1)
head_2.alignment = WD_ALIGN_PARAGRAPH.CENTER
h_fmt = head_2.paragraph_format
h_fmt.line_spacing = 1.75
# параграф
paragraph = doc.add_paragraph(f'Всего имеется {check.shape[0]} наблюдений.\n\
Имееются следующие переменные: ')
p_fmt = paragraph.paragraph_format
p_fmt.line_spacing = 1.5
for var in check['DESCRIPTION'].unique():
    paragraph = doc.add_paragraph(f'{var}', style= 'List Number')
    p_fmt = paragraph.paragraph_format
    p_fmt.line_spacing = 1.75
# табличка
miss = check.isna().sum().reset_index()
table = doc.add_table(rows=check.shape[1] + 1, cols=2, style='Table Grid')
cell = table.cell(0, 0)
cell.paragraphs[0].add_run('Название переменной')
cell = table.cell(0, 1)
cell.paragraphs[0].add_run('Количество пропусков в изначальных данных')
for column, value, index in zip(miss['index'], miss[0], range(1, miss.shape[0] + 1)):
    cell = table.cell(index, 0)
    cell.paragraphs[0].add_run(column)
    cell = table.cell(index, 1)
    cell.paragraphs[0].add_run(f'{value}')
# параграф про дубликаты
paragraph = doc.add_paragraph(f'Количество дубликатов в изначальных данных: \
{check.shape[0] - check.drop_duplicates().shape[0]} строчки')
p_fmt = paragraph.paragraph_format
p_fmt.line_spacing = 1.75

# табличка
miss = df.isna().sum().reset_index()
table = doc.add_table(rows=df.shape[1] + 1, cols=2, style='Table Grid')
cell = table.cell(0, 0)
cell.paragraphs[0].add_run('Название переменной')
cell = table.cell(0, 1)
cell.paragraphs[0].add_run('Количество пропусков в данных после обработки (приведенные к широкому формату)')
for column, value, index in zip(miss['DESCRIPTION'], miss[0], range(1, miss.shape[0] + 1)):
    if column == '': column = 'TIMESTAMP'
    cell = table.cell(index, 0)
    cell.paragraphs[0].add_run(column)
    cell = table.cell(index, 1)
    cell.paragraphs[0].add_run(f'{value}')
    
# параграф про дубликаты
paragraph = doc.add_paragraph(f'Количество дубликатов в данных после обработки: \
{df.shape[0] - df.drop_duplicates().shape[0]} строчки')
p_fmt = paragraph.paragraph_format
p_fmt.line_spacing = 1.75

# подглава про выбросы
head_3 = doc.add_heading('Детекция выбросов', level = 2)
head_2.alignment = WD_ALIGN_PARAGRAPH.CENTER
h_fmt = head_2.paragraph_format
h_fmt.line_spacing = 1.75

# текст с табличкой 
paragparh = doc.add_paragraph('В таблице предоставленны данные о выбросах')
p_fmt = paragraph.paragraph_format
p_fmt.line_spacing = 1.75
table = doc.add_table(rows = 5, cols = 9, style = 'Table Grid')
cell = table.cell(0, 0)
cell.paragraphs[0].add_run('Название метода\Название переменной')
cell = table.cell(1, 0)
cell.paragraphs[0].add_run('z-score (абсолютный)')
cell = table.cell(2, 0)
cell.paragraphs[0].add_run('z-score (в процентах)')
cell = table.cell(3, 0)
cell.paragraphs[0].add_run('IQR (абсолютный)')
cell = table.cell(4, 0)
cell.paragraphs[0].add_run('IQR (в процентах)')
for i in range(0, 8):
    cell = table.cell(0, i + 1)
    cell.paragraphs[0].add_run(df.columns.droplevel(0)[i + 1])
    cell = table.cell(1, i + 1)
    cell.paragraphs[0].add_run(f'{len(dict_out_feat_z[df.columns[i + 1]])}')
    cell = table.cell(2, i + 1)
    cell.paragraphs[0].add_run(f'{(len(dict_out_feat_z[df.columns[i + 1]]) / df.shape[0]) * 100 :.1f} %')
    cell = table.cell(3, i + 1)
    cell.paragraphs[0].add_run(f'{len(dict_out_feat_iqr[df.columns[i + 1]][0])}')
    cell = table.cell(4, i + 1)
    cell.paragraphs[0].add_run(f'{(len(dict_out_feat_iqr[df.columns[i + 1]][0]) / df.shape[0]) * 100:.1f} %')

# новая глава: машинное обучение
head_4 = doc.add_heading('Результаты машинного обучения', level = 1)
# подглава: линейные модели
head_5 = doc.add_heading('Линейные модели', level = 2)
table = doc.add_table(metrics_linear.shape[0]+1, metrics_linear.shape[1], style='Table Grid')
for j in range(metrics_linear.shape[-1]):
    table.cell(0,j).text = metrics_linear.columns[j]
for i in range(metrics_linear.shape[0]):
    for j in range(metrics_linear.shape[-1]):
        table.cell(i+1,j).text = str(metrics_linear.values[i,j])
# подглава: деревянные модели   
head_6 = doc.add_heading('Деревянные модели', level = 2)
table = doc.add_table(metrics_tree.shape[0] + 1, metrics_tree.shape[1], style='Table Grid')
for j in range(metrics_tree.shape[-1]):
    table.cell(0,j).text = metrics_tree.columns[j]
for i in range(metrics_tree.shape[0]):
    for j in range(metrics_tree.shape[-1]):
        table.cell(i+1,j).text = str(metrics_tree.values[i,j])
        
# подглава: бустинги
head_6 = doc.add_heading('Модели бустинга', level = 2)
table = doc.add_table(metrics_boost.shape[0] + 1, metrics_boost.shape[1], style='Table Grid')
for j in range(metrics_boost.shape[-1]):
    table.cell(0,j).text = metrics_boost.columns[j]
for i in range(metrics_boost.shape[0]):
    for j in range(metrics_boost.shape[-1]):
        table.cell(i+1,j).text = str(metrics_boost.values[i,j])
# сохранение 
doc.save('Первичный осмотр.docx')

# %%
doc.paragraphs
